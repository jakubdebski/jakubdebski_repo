# %% [markdown]
# # Jakub Dębski - laboratorium 1

# %% [markdown]
# Importy

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Zadanie 3

# %%
function = lambda x: x**2 + 5
args_1 = np.linspace(-1, 1)
args_2 = np.linspace(-6, 6)
args_3 = np.linspace(0, 5)

plt.plot(args_1, function(args_1), label="y = x^2 + 5")
plt.xlabel("arguments")
plt.ylabel("values")
plt.title('x>-1, x<1')
plt.legend()
plt.grid()
plt.show()

plt.plot(args_2, function(args_2), label="y = x^2 + 5")
plt.xlabel("arguments")
plt.ylabel("values")
plt.title('x>-6, x<6')
plt.legend()
plt.grid()
plt.show()

plt.plot(args_3, function(args_3), label="y = x^2 + 5")
plt.xlabel("arguments")
plt.ylabel("values")
plt.title('x>0, x<5')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Zadanie 4

# %%
d = {'name': ['Jakub', 'Kamil', 'Wiktoria', 'Karolina', 'Michał'], 'surname': ['Dębski', 'Nowak', 'Kowalska', 'Wiśniewska', 'Lewandowski'], 'age': [20, 40, 51, 60, 99], 'sex': ['man', 'man', 'woman', 'woman', 'man']}
df = pd.DataFrame(data=d)
df
# Out:
#        name      surname  age    sex
# 0     Jakub       Dębski   20    man
# 1     Kamil        Nowak   40    man
# 2  Wiktoria     Kowalska   51  woman
# 3  Karolina   Wiśniewska   60  woman
# 4    Michał  Lewandowski   99    man

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     5 non-null      object
#  1   surname  5 non-null      object
#  2   age      5 non-null      int64
#  3   sex      5 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 288.0+ bytes

# %%
df.describe()
# Out:
#              age
# count   5.000000
# mean   54.000000
# std    29.248932
# min    20.000000
# 25%    40.000000
# 50%    51.000000
# 75%    60.000000
# max    99.000000

# %%
df.head(3)
# Out:
#        name   surname  age    sex
# 0     Jakub    Dębski   20    man
# 1     Kamil     Nowak   40    man
# 2  Wiktoria  Kowalska   51  woman
